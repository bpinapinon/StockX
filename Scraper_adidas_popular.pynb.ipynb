# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import requests
import time
from splinter import Browser
import csv
import pandas as pd

# %%
url_list = ["https://stockx.com/adidas-yeezy-boost-350-v2-beluga-2-0",
    "https://stockx.com/adidas-yeezy-boost-350-v2-butter",
    "https://stockx.com/adidas-yeezy-500-blush",
    "https://stockx.com/adidas-yeezy-boost-350-v2-blue-tint",
    "https://stockx.com/adidas-yeezy-wave-runner-700-solid-grey",
    "https://stockx.com/adidas-yeezy-500-utility-black",
    "https://stockx.com/adidas-yeezy-boost-350-v2-cream-white",
    "https://stockx.com/adidas-yeezy-500-desert-rat-moon-yellow",
    "https://stockx.com/adidas-yeezy-boost-350-v2-white-core-black-red",
    "https://stockx.com/adidas-yeezy-powerphase-calabasas-core-black", 
    "https://stockx.com/adidas-yeezy-powerphase-calabasas-grey",
    "https://stockx.com/adidas-yeezy-boost-350-v2-semi-frozen-yellow",
    "https://stockx.com/adidas-ultra-boost-4pt0-triple-black",
    "https://stockx.com/adidas-nmd-xr1-og-black",
    "https://stockx.com/adidas-human-race-nmd-pharrell-holi-festival-core-black",
    "https://stockx.com/adidas-ultra-boost-4-0-running-white",
    "https://stockx.com/adidas-human-race-nmd-pharrell-holi-festival",
    "https://stockx.com/adidas-yeezy-powerphase-calabasas-core-white",
    "https://stockx.com/adidas-human-race-nmd-pharrell-holi-festival-pink-glow",
    "https://stockx.com/adidas-nmd-r1-japan-triple-white",
    "https://stockx.com/adidas-yeezy-boost-350-v2-core-black-red-2017",
    "https://stockx.com/adidas-ultra-boost-4-oreo",
    "https://stockx.com/adidas-ultra-boost-4pt0-core-black",
    "https://stockx.com/adidas-nmd-r1-japan-triple-black",
    "https://stockx.com/adidas-human-race-nmd-pharrell-oreo",
    "https://stockx.com/adidas-human-race-nmd-pharrell-cream",
    "https://stockx.com/adidas-human-race-nmd-pharrell-multi-color",
    "https://stockx.com/adidas-human-race-nmd-pharrell-pale-nude",
    "https://stockx.com/adidas-dame-4-a-bathing-ape-camo",
    "https://stockx.com/adidas-ultra-boost-mid-kith-x-nonnative",
    "https://stockx.com/adidas-nmd-r1-stlt-triple-black",
    "https://stockx.com/adidas-nmd-hu-pharrell-solar-pack-red",
    "https://stockx.com/adidas-ultra-boost-5th-anniversary-black",
    "https://stockx.com/adidas-ultra-boost-3pt0-triple-white",
    "https://stockx.com/adidas-nmd-r1-neighborhood-core-black",
    "https://stockx.com/adidas-yeezy-boost-350-v2-core-black-white",
    "https://stockx.com/adidas-human-race-nmd-pharrell-sun-glow",
    "https://stockx.com/adidas-zx-500-dragon-ball-z-son-goku",
    "https://stockx.com/adidas-nmd-hu-pharrell-mother",
    "https://stockx.com/adidas-yeezy-boost-350-v2-steeple-grey-beluga-solar-red",
    "https://stockx.com/adidas-eqt-support-93-17-triple-black",
    "https://stockx.com/adidas-ultra-boost-4pt0-undftd",
    "https://stockx.com/adidas-ultra-boost-4-breast-cancer-awareness",
    "https://stockx.com/adidas-ultra-boost-4pt0-a-ma-maniere-x-invincible-cashmere-wool",
    "https://stockx.com/adidas-nmd-cs2-core-black-red-solid",
    "https://stockx.com/adidas-yung-1-triple-black",
    "https://stockx.com/adidas-ultra-boost-atr-mid-burgundy",
    "https://stockx.com/adidas-crazy-byw-x-black-white",
    "https://stockx.com/adidas-nmd-r1-clear-pink-w",
    "https://stockx.com/adidas-nmd-hu-china-pack-passion-red",
    "https://stockx.com/adidas-eqt-support-adv-gucci",
    "https://stockx.com/adidas-nmd-cs2-primeknit-ronin-stripes",
    "https://stockx.com/adidas-nmd-racer-juice-hk",
    "https://stockx.com/adidas-nmd-r1-triple-solar-red",
    "https://stockx.com/adidas-i-5923-black-boost",
    "https://stockx.com/adidas-iniki-runner-pride-of-the-70s-usa",
    "https://stockx.com/adidas-crazy-byw-lvl-1-black-white",
    "https://stockx.com/adidas-tennis-hu-pharrell-multi-color",
    "https://stockx.com/adidas-yeezy-boost-750-triple-black",
    "https://stockx.com/adidas-eqt-support-93-17-white-royal",
    "https://stockx.com/adidas-nmd-cs1-parley-blue-spirit",
    "https://stockx.com/adidas-nmd-cs1-gore-tex-white",
    "https://stockx.com/adidas-ultra-boost-3pt0-lgbt",
    "https://stockx.com/adidas-ultra-boost-mid-run-thru-time",
    "https://stockx.com/adidas-dame-4-a-bathing-ape-black"]

# %%
csv_file = open('adidas_popular_sneaker_data.csv', 'w')
writer = csv.writer(csv_file)
writer.writerow(['Model','Color','Retail_Price', 'Release_Date', 'Number_of_Sales', 'Price_Premium', 'Avg_Sale_Price'])

# %%
def sneakerscrape():
    #time.sleep(20)
    
    #Get model of sneaker
    model = soup.find('h1', class_='name').text
    print(model)
    
    time.sleep(5)
    #Get product details
    detail_attr = soup.find_all('div', class_='detail')
    details = []
    for detail in detail_attr:
        span = detail.text
        details.append(span)
    print("test2")

    
    #Get stats on sneaker sales/premiums
    stats_attr = soup.find_all('div', class_='gauge-value')
    stats=[]
    for stat in stats_attr:
        item = stat.text
        stats.append(item)
    print("test3")
    
    #strip strings
    color = details[1]
    color = color.replace("Colorway ", "")
    print("test5")
    
    retail = details[2]
    retail = retail.replace("Retail Price ", "")
    print("test6")
    
    release = details[3]
    release = release.replace("Release Date ", "")
    print("test7")
    
    

    #dictionary to hold values
    sneakers = {}


    sneakers['Model'] = model
    sneakers['Color'] = color
    sneakers['Retail_Price'] = retail
    sneakers['Release_Date'] = release
    sneakers['Number_of_Sales'] = stats[0]
    sneakers['Price_Premium'] = stats[1]
    sneakers['Avg_Sale_Price'] = stats[2]
    
    #write row in csv
    writer.writerow(sneakers.values())
    print("test")

# %%
try:
    for url in url_list:
        executable_path = {'executable_path': 'chromedriver'}
        browser = Browser('chrome', **executable_path)
        browser.visit(url)
        time.sleep(10)
        
        # Retrieve page with the requests module
        response = requests.get(url)
        # Create BeautifulSoup object; parse with 'lxml'
        soup = bs(response.text, 'lxml')
        sneakerscrape()

except AttributeError as e:
    print(e)
    print(url)
    pass
    
    #csv_file.close()

# %%
csv_file.close()
