# %%
# Dependencies
import os
from bs4 import BeautifulSoup as bs
import requests
import time
from splinter import Browser
import csv
import pandas as pd

# %%
url_list = [#"https://stockx.com/nike-blazer-mid-off-white-all-hallows-eve",
    #"https://stockx.com/nike-blazer-mid-off-white-grim-reaper",
    #"https://stockx.com/nike-air-presto-mid-acronym-racer-pink",
    #"https://stockx.com/nike-air-presto-mid-acronym-cool-grey",
    #"https://stockx.com/nike-air-presto-mid-acronym-dynamic-yellow",
    #"https://stockx.com/nike-air-force-1-ultra-flyknit-low-rkk-new-england-patriots-2018",
    #"https://stockx.com/nike-react-element-87-blue-chill-solar-red",
    #"https://stockx.com/nike-zoom-fly-undercover-gyakusou-black",
    #"https://stockx.com/nike-zoom-fly-undercover-gyakusou",
    #"https://stockx.com/nike-air-force-1-low-travis-scott-sail",
    #"https://stockx.com/nike-air-presto-off-white-white-2018",
    #"https://stockx.com/nike-air-force-1-low-white-2016",
    #"https://stockx.com/nike-air-max-270-bowfin-black-desert",
    #"https://stockx.com/nike-react-element-87-knicks",
    #"https://stockx.com/nike-lebron-16-what-the",
    #"https://stockx.com/nike-air-presto-off-white-black-2018",
    #"https://stockx.com/nike-react-element-55-black-aurora-green",
    #"https://stockx.com/nike-react-element-87-undercover-green-mist",
    #"https://stockx.com/nike-lebron-16-fresh-bred",
    #"https://stockx.com/nike-sb-dunk-high-humidity",
    #"https://stockx.com/nike-zoom-fly-undercover-gyakusou-ink",
    #"https://stockx.com/nike-air-force-1-low-just-do-it-pack-white-black",
    #"https://stockx.com/nike-air-max-1-97-sean-wotherspoon-na",
    #"https://stockx.com/nike-air-foamposite-one-denim",
    #"https://stockx.com/nike-react-element-87-undercover-volt",
    #"https://stockx.com/nike-react-element-87-undercover-light-beige-chalk",
    #"https://stockx.com/nike-zoom-vaporfly-4-flyknit-bright-crimson",
    #"https://stockx.com/nike-react-element-87-sail-light-bone",
    #"https://stockx.com/nike-zoom-fly-mercurial-off-white-total-orange",
    #"https://stockx.com/nike-air-force-1-low-utility-white-black",
    #"https://stockx.com/nike-air-force-1-air-foamposite-cup-triple-black",
    #"https://stockx.com/nike-react-element-87-black-neptune-green",
    #"https://stockx.com/nike-sb-gato-supreme-white",
    #"https://stockx.com/nike-react-element-87-desert-sand",
    #"https://stockx.com/nike-air-max-1-atmos-animal-pack-2-2018-black-box",
    #"https://stockx.com/nike-zoom-fly-mercurial-off-white-black",
    #"https://stockx.com/nike-zoom-fly-sp-breaking-2-2018",
    #"https://stockx.com/nike-react-element-55-black-white",
    #"https://stockx.com/nike-air-air-foamposite-pro-sequoia",
    #"https://stockx.com/air-jordan-1-mid-south-beach",
    #"https://stockx.com/air-jordan-1-retro-high-pine-green",
    #"https://stockx.com/air-jordan-1-retro-high-court-purple",
    #"https://stockx.com/air-jordan-5-retro-wings",
    #"https://stockx.com/air-jordan-6-retro-tinker",
    #"https://stockx.com/air-jordan-1-mid-south-beach-gs",
    #"https://stockx.com/air-jordan-1-retro-high-court-purple-gs",
    #"https://stockx.com/air-jordan-1-retro-high-shadow-2018",
    #"https://stockx.com/air-jordan-5-retro-grape-fresh-prince",
    #"https://stockx.com/air-jordan-1-mid-gym-red-black",
    #"https://stockx.com/air-jordan-1-retro-high-alternate-black-royal",
    #"https://stockx.com/air-jordan-1-retro-high-homage-to-home-nn",
    #"https://stockx.com/air-jordan-4-retro-travis-scott-cactus-jack",
    #"https://stockx.com/air-jordan-1-retro-high-bred-toe",
    #"https://stockx.com/air-jordan-6-retro-tinker-gs",
    #"https://stockx.com/air-jordan-1-retro-high-off-white-university-blue",
    #"https://stockx.com/air-jordan-3-retro-black-cement-2018",
    #"https://stockx.com/air-jordan-1-retro-high-pine-green-gs",
    #"https://stockx.com/air-jordan-1-retro-high-patent-gold-toe",
    #"https://stockx.com/air-jordan-12-retro-international-pack",
    #"https://stockx.com/air-jordan-5-retro-international-flight",
    #"https://stockx.com/air-jordan-3-retro-tinker-hatfield",
    #"https://stockx.com/air-jordan-5-retro-wings-gs",
    #"https://stockx.com/air-jordan-4-retro-raptors",
    #"https://stockx.com/air-jordan-13-retro-he-got-game-2018",
    #"https://stockx.com/air-jordan-11-retro-win-like-96",
    #"https://stockx.com/air-jordan-1-retro-high-clay-green",
    #"https://stockx.com/air-jordan-1-retro-high-shadow-2018-gs",
    #"https://stockx.com/air-jordan-3-retro-jth-bio-beige",
    #"https://stockx.com/air-jordan-1-retro-high-nigel-sylvester",
    #"https://stockx.com/air-jordan-13-retro-he-got-game-2018-gs",
    #"https://stockx.com/air-jordan-10-retro-tinker",
    #"https://stockx.com/air-jordan-1-retro-black-blue-2017",
    #"https://stockx.com/jordan-11-retro-space-jams-2016",
    #"https://stockx.com/air-jordan-1-retro-high-blue-moon",
    #"https://stockx.com/air-jordan-11-retro-platinum-tint",
    #"https://stockx.com/air-jordan-1-mid-multi-color-swoosh-gs",
    #"https://stockx.com/air-jordan-11-retro-prom-night",
    #"https://stockx.com/air-jordan-5-retro-paris-saint-germain",
    #"https://stockx.com/air-jordan-1-mid-gym-red-black-gs",
    #"https://stockx.com/nike-air-vapormax-off-white-2018",
    #"https://stockx.com/nike-air-vapormax-off-white-black",
    #"https://stockx.com/nike-air-force-1-mid-supreme-nba-black",
    #"https://stockx.com/nike-air-max-97-metallic-gold-2018",
    #"https://stockx.com/nike-cortez-kenny-3-kendrick-lamar-tde-the-championship",
    #"https://stockx.com/nike-air-foamposite-alternate-galaxy",
    #"https://stockx.com/nike-air-max-97-off-white",
    #"https://stockx.com/nike-blazer-mid-off-white",
    #"https://stockx.com/nike-zoom-fly-off-white",
    #"https://stockx.com/nike-react-hyperdunk-2017-flyknit-off-white",
    #"https://stockx.com/nike-kobe-1-protro-undefeated",
    #"https://stockx.com/nike-air-vapormax-plus-triple-black",
    #"https://stockx.com/nike-air-force-1-low-clot-1world-2018",
    #"https://stockx.com/nike-kobe-1-protro-think-16-close-out",
    #"https://stockx.com/nike-lunar-force-1-low-acronym-af100",
    #"https://stockx.com/nike-kyrie-4-confetti",
    #"https://stockx.com/nike-kobe-1-protro-black-maize",
    #"https://stockx.com/nike-kyrie-4-cinnamon-toast-crunch",
    #"https://stockx.com/nike-air-max-270-dusty-cactus",
    #"https://stockx.com/nike-air-max-1-watermelon",
    #"https://stockx.com/nike-lebron-icon-john-elliott-white",
    #"https://stockx.com/nike-air-force-1-high-just-don-af100",
    #"https://stockx.com/air-jordan-1-retro-mid-new-love-2017",
    #"https://stockx.com/air-jordan-18-retro-red-suede",
    "https://stockx.com/air-jordan-13-retro-alternate-history-of-flight",
    "https://stockx.com/air-jordan-1-retro-high-gatorade-cyber",
    "https://stockx.com/air-jordan-11-air-jordan-11-retro-win-like-96-gs",
    "https://stockx.com/jordan-12-retro-flu-game-2016",
    "https://stockx.com/air-jordan-1-retro-high-gatorade-orange-peel",
    "https://stockx.com/air-jordan-13-retro-altitudes-2017",
    "https://stockx.com/air-jordan-6-retro-wheat"]

# %%
csv_file = open('nike_popular_sneaker_data.csv', 'w')
writer = csv.writer(csv_file)
writer.writerow(['Model','Color','Retail_Price', 'Release_Date', 'Number_of_Sales', 'Price_Premium', 'Avg_Sale_Price'])
# Out:
# 84

# %%
def sneakerscrape():
    #time.sleep(20)
    
    #Get model of sneaker
    model = soup.find('h1', class_='name').text
    print(model)
    
    time.sleep(5)
    #Get product details
    detail_attr = soup.find_all('div', class_='detail')
    details = []
    for detail in detail_attr:
        span = detail.text
        details.append(span)
    print("test2")

    
    #Get stats on sneaker sales/premiums
    stats_attr = soup.find_all('div', class_='gauge-value')
    stats=[]
    for stat in stats_attr:
        item = stat.text
        stats.append(item)
    print("test3")
    
    #strip strings
    color = details[1]
    color = color.replace("Colorway ", "")
    print("test5")
    
    retail = details[2]
    retail = retail.replace("Retail Price ", "")
    print("test6")
    
    release = details[3]
    release = release.replace("Release Date ", "")
    print("test7")
    
    

    #dictionary to hold values
    sneakers = {}


    sneakers['Model'] = model
    sneakers['Color'] = color
    sneakers['Retail_Price'] = retail
    sneakers['Release_Date'] = release
    sneakers['Number_of_Sales'] = stats[0]
    sneakers['Price_Premium'] = stats[1]
    sneakers['Avg_Sale_Price'] = stats[2]
    
    #write row in csv
    writer.writerow(sneakers.values())
    print("test")

# %%
try:
    for url in url_list:
        executable_path = {'executable_path': 'chromedriver'}
        browser = Browser('chrome', **executable_path)
        browser.visit(url)
        time.sleep(10)
        
        # Retrieve page with the requests module
        response = requests.get(url)
        # Create BeautifulSoup object; parse with 'lxml'
        soup = bs(response.text, 'lxml')
        sneakerscrape()

except AttributeError as e:
    print(e)
    print(url)
    pass
    
    #csv_file.close()
# Out:
# Jordan 13 Retro Alternate History of Flight
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 1 Retro High Gatorade Cyber
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 11 Retro Win Like 96 (GS)
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 12 Retro Flu Game (2016)
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 1 Retro High Gatorade Orange Peel
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 13 Retro Altitude (2017)
# test2
# test3
# test5
# test6
# test7
# test
# Jordan 6 Retro Wheat
# test2
# test3
# test5
# test6
# test7
# test

# %%
csv_file.close()
